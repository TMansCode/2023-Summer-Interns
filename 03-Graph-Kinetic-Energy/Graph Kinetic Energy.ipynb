# %%
table = {
    "Speeds": ["school", "town", "highway"],
    "Kia": ["45971.246096989365", "413330.24771189416", "862248.515805347"],
    "Ford": ["61420.93409004688", "552239.3247416801", "1152026.837532022"],
    "Fiat": ["33748.32704365834", "303433.24493287655", "632992.3022515931"],
    "Dodge": ["41590.60092248727", "373943.6026056297", "780084.0081908437"]
}

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Create the dataframe
data = {'KIA': [45971.25, 413330.25, 862248.52],
        'FORD': [61420.93, 552239.32, 1152026.84],
        'FIAT': [33748.33, 303433.24, 632992.30],
        'DODGE': [41590.60, 373943.60, 780084.01]}
index = ['Schools', 'Towns', 'Highway']


# to convert our dictionary to a dataframe
#df = pd.DataFrame(table)

df = pd.DataFrame(data, index=index)

# Plot the dataframe
df.plot(kind='line')

# Set the labels and titl
plt.xlabel('Category')
plt.ylabel('Value')
plt.title('Data Plot')

# Display the plot
plt.show()
